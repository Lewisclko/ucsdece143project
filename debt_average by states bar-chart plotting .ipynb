# %%
#Author: Datzael Gomez
#Data Dictionary Variables 
'''
Because the data in excel sheet doesn't have well defined variable names it is not easy to know
what data is needed for the analysis, therefore an extra step is needed to 
remove all the unnessary data and translate what each variable signifies using 
a data dictionary that is provided. The end goal is to remove all the unecessary data and change the variable names to 
more definite and understandable names.
'''
import pandas as pd
import numpy as np
import os 
os.chdir('C:\Users\Lewis\Desktop\scorecard_data')
#load Data dictionay using pandas
df_dictionary = pd.read_csv('CollegeScorecardDataDictionarydata_dictionary.csv')
#only want to look at variable name and their significance
df_translate= df_dictionary[['NAME OF DATA ELEMENT','VARIABLE NAME']]
#Drop any NaN inputs
df_translate= df_translate.dropna()
#save variable indexes
#SAT
x= df_translate.loc[df_translate['NAME OF DATA ELEMENT'].str.contains('SAT')]
y= x.index.get_values()
#ACT
x= df_translate.loc[df_translate['NAME OF DATA ELEMENT'].str.contains('ACT')]
y=np.append(y,x.index.get_values())
y= np.delete(y, 9)
y = np.delete(y,9)
#ethinic
x= df_translate.loc[df_translate['NAME OF DATA ELEMENT'].str.contains('Total share of enrollment of undergraduate degree-seeking students')]
y=np.append(y,x.index.get_values())
#retention rates
x= df_translate.loc[df_translate['NAME OF DATA ELEMENT'].str.contains('First-time, full-time student retention rate at four-year institutions')]
y=np.append(y,x.index.get_values())
#female,male,married,stuff
x= df_translate.loc[df_translate['NAME OF DATA ELEMENT'].str.contains('Share of')]
y=np.append(y,x.index.get_values())
y=y[:-10]
y=np.delete(y,-10)
y=np.delete(y,-9)
y=np.delete(y,-8)
y=np.delete(y,-7)
y=np.delete(y,-6)
#debt
x= df_translate.loc[df_translate['NAME OF DATA ELEMENT'].str.contains('The median debt for')]
y=np.append(y,x.index.get_values())
x= df_translate.loc[df_translate['NAME OF DATA ELEMENT'].str.contains('Enrollment')]
y=np.append(y,x.index.get_values())
y=np.append(y,[3,4,5,6])
x= df_translate.loc[df_translate['NAME OF DATA ELEMENT'].str.contains('Longitude')]
y=np.append(y,x.index.get_values())
x= df_translate.loc[df_translate['NAME OF DATA ELEMENT'].str.contains('Latitude')]
y=np.append(y,x.index.get_values())
y.sort()
df= df_translate.ix[y]
df_names=df['VARIABLE NAME'].tolist()
df2016 = pd.read_csv('MERGED2015_16_PP.csv')
df2016= df2016[df_names]

#Need to break everything down into categories #Need to  
#Start with ethnicity starts with UDGS
y=[]
df_temp= df.loc[df['VARIABLE NAME'].str.contains('UG')]
y=np.append(y,df_temp.index.get_values())
df_temp= df.loc[df['VARIABLE NAME'].str.contains('CITY')]
y=np.append(y,df_temp.index.get_values())
y.sort()
df_temp= df.ix[y]
ethnic = df_temp['VARIABLE NAME'].tolist()
df_ethnic = df2016[ethnic]
len(y)
m=[]
for i in range(len(y)):
    q = df_ethnic.loc[1].isnull()
    if q[i] == False:
        m=np.append(m,ethnic[i])
df_ethnic= df_ethnic[m]  
df_ethnic.dropna()
# Out:
# C:\Users\Lewis\Anaconda2\lib\site-packages\ipykernel_launcher.py:55: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# C:\Users\Lewis\Anaconda2\lib\site-packages\ipykernel_launcher.py:68: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#                   CITY     UGDS  UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# 0               Normal   4505.0      0.0340      0.9216     0.0058
# 1           Birmingham  11269.0      0.5863      0.2541     0.0317
# 2           Montgomery    308.0      0.2110      0.3409     0.0195
# 3           Huntsville   5829.0      0.7024      0.1230     0.0417
# 4           Montgomery   4740.0      0.0165      0.9251     0.0116
# 5           Tuscaloosa  31005.0      0.7807      0.1092     0.0399
# 6       Alexander City   1546.0      0.7141      0.2600     0.0123
# 7               Athens   2904.0      0.7817      0.1185     0.0189
# 7126      0.0043     0.0014     0.0014     0.0072    0.0000     0.1795
# 7127      0.0000     0.0000     0.0000     0.0245    0.0000     0.5140
# 7128      0.0145     0.0000     0.0087     0.1272    0.0000     0.1243
# 7129      0.0106     0.0000     0.0000     0.0106    0.0000     0.2014
# 7130      0.0037     0.0000     0.0000     0.0000    0.0000     0.2601
# 7131      0.0057     0.0000     0.0000     0.1379    0.0000     0.0345
# 7132      0.0064     0.0043     0.0021     0.0192    0.0021     0.1919
# 7133      0.0068     0.0000     0.0000     0.0000    0.0000     0.7891
# 7134      0.0000     0.0027     0.0000     0.0027    0.0000     0.3636
# 7135      0.0566     0.0189     0.0000     0.0189    0.0000     0.0000
# 7136      0.0070     0.0050     0.0031     0.0124    0.0309     0.0073
# 7137      0.0000     0.0000     0.0000     0.0156    0.0156     0.0000
# 7138      0.0000     0.0000     0.0000     0.0219    0.0036     0.0182
# 7139      0.0491     0.0000     0.0140     0.0877    0.0000     0.0596
# 7140      0.0501     0.0173     0.0190     0.0466    0.0000     0.1036
# 7141      0.0000     0.0000     0.0000     0.0000    0.0000     0.0000
# 7142      0.0000     0.0000     0.0000     0.0000    0.0000     0.0000
# 7144      0.0508     0.0000     0.0169     0.0000    0.0000     0.1186
# 7145      0.2832     0.0000     0.0133     0.0044    0.5442     0.0000
# 7146      0.0000     0.0000     0.0000     0.0156    0.0156     0.0156
#
#       UGDS_MEN  UGDS_WOMEN
# 0       0.4617      0.5383
# 1       0.4116      0.5884
# 2       0.4286      0.5714
# 3       0.5740      0.4260
# 4       0.3850      0.6150
# 5       0.4525      0.5475
# 6       0.4017      0.5983
# 7       0.3485      0.6515
# 8       0.3595      0.6405
# 9       0.5095      0.4905
# 10      0.5022      0.4978
# 11      0.3870      0.6130
# 12      0.5541      0.4459
# 13      0.2500      0.7500
# 14      0.5177      0.4823
# 15      0.3840      0.6160
# 16      0.3874      0.6126
# 17      0.3909      0.6091
# 18      0.0000      1.0000
# 19      0.3412      0.6588
# 20      0.3700      0.6300
# 21      0.3427      0.6573
# 22      0.4889      0.5111
# 23      0.4991      0.5009
# 24      0.9483      0.0517
# 25      0.4524      0.5476
# 26      0.4312      0.5688
# 27      0.4392      0.5608
# 28      0.3842      0.6158
# 29      0.4483      0.5517
# ...        ...         ...
# 7116    0.2650      0.7350
# 7117    0.9551      0.0449
# 7118    0.6594      0.3406
# 7119    0.0000      1.0000
# 7120    0.1034      0.8966
# 7121    0.1707      0.8293
# 7122    0.0000      0.0000
# 7123    0.3878      0.6122
# 7124    0.4343      0.5657
# 7125    0.4310      0.5690
# 7126    0.2822      0.7178
# 7127    0.5524      0.4476
# 7128    0.2861      0.7139
# 7129    0.2721      0.7279
# 7130    0.4176      0.5824
# 7131    0.2816      0.7184
# 7132    0.5011      0.4989
# 7133    0.5986      0.4014
# 7134    0.4519      0.5481
# 7135    0.0000      1.0000
# 7136    0.4687      0.5313
# 7137    0.0781      0.9219
# 7138    0.0255      0.9745
# 7139    0.9754      0.0246
# 7140    0.5682      0.4318
# 7141    0.8889      0.1111
# 7142    0.5385      0.4615
# 7144    0.8475      0.1525
# 7145    0.4027      0.5973
# 7146    0.0781      0.9219
#
# [6858 rows x 13 columns]

# %%
def names():
    #Author: Datzael Gomez
    #Data Dictionary Variables 
    '''
    Because the data in excel sheet doesn't have well defined variable names it is not easy to know
    what data is needed for the analysis, therefore an extra step is needed to 
    remove all the unnessary data and translate what each variable signifies using 
    a data dictionary that is provided. The end goal is to remove all the unecessary data and change the variable names to 
    more definite and understandable names.
    '''
    import pandas as pd
    import numpy as np
    #load Data dictionay using pandas
    df_dictionary = pd.read_csv('CollegeScorecardDataDictionarydata_dictionary.csv')
    #only want to look at variable name and their significance
    df_translate= df_dictionary[['NAME OF DATA ELEMENT','VARIABLE NAME']]
    #Drop any NaN inputs
    df_translate= df_translate.dropna()
    #save variable indexes
    x= df_translate.loc[df_translate['NAME OF DATA ELEMENT'].str.contains('SAT')]
    y= x.index.get_values()
    x= df_translate.loc[df_translate['NAME OF DATA ELEMENT'].str.contains('ACT')]
    y=np.append(y,x.index.get_values())
    y= np.delete(y, 9)
    y = np.delete(y,9)
    x= df_translate.loc[df_translate['NAME OF DATA ELEMENT'].str.contains('Total share of enrollment of undergraduate degree-seeking students')]
    y=np.append(y,x.index.get_values())
    x= df_translate.loc[df_translate['NAME OF DATA ELEMENT'].str.contains('First-time, full-time student retention rate at four-year institutions')]
    y=np.append(y,x.index.get_values())
    x= df_translate.loc[df_translate['NAME OF DATA ELEMENT'].str.contains('Share of')]
    y=np.append(y,x.index.get_values())
    y=y[:-10]
    y=np.delete(y,-10)
    y=np.delete(y,-9)
    y=np.delete(y,-8)
    y=np.delete(y,-7)
    y=np.delete(y,-6)
    x= df_translate.loc[df_translate['NAME OF DATA ELEMENT'].str.contains('The median debt for')]
    y=np.append(y,x.index.get_values())
    x= df_translate.loc[df_translate['NAME OF DATA ELEMENT'].str.contains('Enrollment')]
    y=np.append(y,x.index.get_values())
    y=np.append(y,[3,4,5,6])
    x= df_translate.loc[df_translate['NAME OF DATA ELEMENT'].str.contains('Longitude')]
    y=np.append(y,x.index.get_values())
    x= df_translate.loc[df_translate['NAME OF DATA ELEMENT'].str.contains('Latitude')]
    y=np.append(y,x.index.get_values())
    y.sort()
    df= df_translate.ix[y]
    df_names=df['VARIABLE NAME'].tolist()
    df_names.append('INSTNM')
    
    return df_names, df

# %%
#Author: Datzael Gomez
#Ethnicity function
def ethnicity(m, df_names, df):
    import numpy as np
    '''
    this function will look at all columns related to ethnicity and remove any nan's and make a new data frame with the 
    name of the institution attached.
    '''
    assert isinstance(m,basestring), 'string type only'
    import pandas as pd
    df2016 = pd.read_csv(m)
    df2016= df2016[df_names]
    y=[]
    # Get all the columns of interest by their variable names taken directly from 
    df_temp= df.loc[df['VARIABLE NAME'].str.contains('UG')]
    y=np.append(y,df_temp.index.get_values())
    df_temp= df.loc[df['VARIABLE NAME'].str.contains('CITY')]
    y=np.append(y,df_temp.index.get_values())
    y.sort()
    df_temp= df.ix[y]
    ethnic = df_temp['VARIABLE NAME'].tolist()
    ethnic.append('INSTNM')
    df_ethnic = df2016[ethnic]
    len(y)
    m=[]
    for i in range(len(y)):
        q = df_ethnic.loc[1].isnull()
        if q[i] == False:
            m=np.append(m,ethnic[i])
    
    
    m=np.append(m,ethnic[len(y)])
    
    df_ethnic= df_ethnic[m] 
    df_ethnic = df_ethnic.dropna()
    df_ethnic= df_ethnic.T.drop_duplicates().T
    return df_ethnic

# %%
def long_lat(m):
    import pandas as pd
    import numpy as np
    '''
    This function takes in a data an then returns the 
    '''
    df_dictionary = pd.read_csv('CollegeScorecardDataDictionarydata_dictionary.csv')
    #only want to look at variable name and their significance
    df_translate= df_dictionary[['NAME OF DATA ELEMENT','VARIABLE NAME']]
    #Drop any NaN inputs
    df_translate= df_translate.dropna()
    y=[]
    x= df_translate.loc[df_translate['NAME OF DATA ELEMENT'].str.contains('Longitude')]
    y=np.append(y,x.index.get_values())
    x= df_translate.loc[df_translate['NAME OF DATA ELEMENT'].str.contains('Latitude')]
    y=np.append(y,x.index.get_values())
    y.sort()
    df= df_translate.ix[y]
    df_names=df['VARIABLE NAME'].tolist()
    df_names.append('INSTNM')
    df2016 = pd.read_csv('MERGED2015_16_PP.csv')
    df2016= df2016[df_names]
    t2 = m['INSTNM'].tolist()
    l1=[]
    l2=[]
    for i in range(len(m['INSTNM'])):
        e = df2016[df2016['INSTNM']== t2[i]]
        if len(e) > 0:
            df_t=  df2016[df2016['INSTNM']==t2[i]]
            temp1=df_t['LONGITUDE'].tolist()
            temp2=df_t['LATITUDE'].tolist()
            l1.append(temp1[0])
            l2.append(temp2[0])
        else:
            l1.append(0)
            l2.append(0)
        
    dft= pd.DataFrame({'LONGITUDE':l1,'LATITUDE':l2})
    df_longlat= pd.concat([dft, m],axis=1, join_axes=[dft.index])
    return df_longlat

# %%
#Debt stuff
#Author: Datzael Gomez
#debt function
def debt(m, df_names, df1):
    '''
    this function will look at all columns related to debt and remove any rows that have a privacysuppressed value 
    and make a new data frame
    '''
    assert isinstance(m,basestring), 'string type only'
    import pandas as pd
    import numpy as np
    df = pd.read_csv(m)
    df= df[df_names]
    y=[]
    df_temp= df1.loc[df1['VARIABLE NAME'].str.contains('DEBT')]
    y=np.append(y,df_temp.index.get_values())
    df_temp= df1.loc[df1['VARIABLE NAME'].str.contains('CITY')]
    y=np.append(y,df_temp.index.get_values())
    df_temp= df1.loc[df1['VARIABLE NAME'].str.contains('INSTNM')]
    y=np.append(y,df_temp.index.get_values())
    df_temp= df1.loc[df1['VARIABLE NAME'].str.contains('STABBR')]
    y=np.append(y,df_temp.index.get_values())
    y.sort()
    df_temp= df1.ix[y]
    col = df_temp['VARIABLE NAME'].tolist()
    df_debt = df[col]
    len(y)
    m=[]
    for i in range(len(y)):
        q= col
        df_debt=df_debt[df_debt[q[i]] != 'PrivacySuppressed'] 
    df_d= df_debt[m]  
    df_d = df_d.dropna()
    
    
    return df_debt
#Debt stuff
#Author: Datzael Gomez
#debt function
def debt_by_state(m, df_names, df1):
    '''
    this function will look at all columns related to debt and remove any rows that have a privacysuppressed value 
    and make a new data frame
    '''
    assert isinstance(m,basestring), 'string type only'
    import pandas as pd
    import numpy as np
    df = pd.read_csv(m)
    df= df[df_names]
    y=[]
    df_temp= df1.loc[df1['VARIABLE NAME'].str.contains('DEBT')]
    y=np.append(y,df_temp.index.get_values())
    df_temp= df1.loc[df1['VARIABLE NAME'].str.contains('STABBR')]
    y=np.append(y,df_temp.index.get_values())
    y.sort()
    df_temp= df1.ix[y]
    col = df_temp['VARIABLE NAME'].tolist()
    df_debt = df[col]
    len(y)
    m=[]
    for i in range(len(y)):
        q= col
        df_debt=df_debt[df_debt[q[i]] != 'PrivacySuppressed'] 
    df_d= df_debt[m]  
    df_d = df_d.dropna()

    
    return df_debt

# %%
def debtAvg(m):
    import pandas as pd
    df_names, df1 = names()
    x= debt_by_state(m, df_names, df1)
    acm=[]
    states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 

              "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 

              "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 

              "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 

              "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]

    for i in range(len(states)):
        dft= x[x['STABBR']== states[i]]
        dft = dft.dropna()
        if sum(map(float,dft['GRAD_DEBT_MDN'].tolist())) != 0:
            acm.append(int(sum(map(float,dft['GRAD_DEBT_MDN'].tolist()))/len(dft['GRAD_DEBT_MDN'].tolist())))
        else: 
            acm.append(sum(map(int,dft['GRAD_DEBT_MDN'].tolist())))
    
        
    df_avg=[states,acm]
    df_avg=pd.DataFrame(df_avg)

    df_avg= df_avg.transpose()

    df_avg=df_avg.rename(index=str, columns={0:"States", 1:"Cumulative debt"})
    
    return df_avg

# %%
'''
auther: Chen-Lin Ko
'''
import os
os.chdir('C:\Users\Lewis\Desktop\scorecard_data')

fname = 'MERGED2015_16_PP.csv'
debtAvg(fname)
# Out:
# C:\Users\Lewis\Anaconda2\lib\site-packages\ipykernel_launcher.py:48: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# C:\Users\Lewis\Anaconda2\lib\site-packages\ipykernel_launcher.py:56: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#    States Cumulative debt
# 0      AL           20737
# 1      AK           16823
# 2      AZ           15541
# 3      AR           16757
# 4      CA           15414
# 5      CO           18833
# 6      CT           15911
# 7      DC           25284
# 8      DE           17552
# 9      FL           19055
# 10     GA           19717
# 11     HI           15231
# 12     ID           19228
# 13     IL           17258
# 14     IN           20177
# 15     IA           20290
# 16     KS           16724
# 17     KY           18538
# 18     LA           16661
# 19     ME           17873
# 20     MD           18254
# 21     MA           19204
# 22     MI           19045
# 23     MN           19122
# 24     MS           16421
# 25     MO           19303
# 26     MT           19226
# 27     NE           20731
# 28     NV           15628
# 29     NH           19793
# 30     NJ           15645
# 31     NM           18264
# 32     NY           17479
# 33     NC           20572
# 34     ND           18215
# 35     OH           20079
# 36     OK           17674
# 37     OR           19458
# 38     PA           20109
# 39     RI           19024
# 40     SC           19786
# 41     SD           24123
# 42     TN           20202
# 43     TX           16184
# 44     UT           17826
# 45     VT           21424
# 46     VA           21330
# 47     WA           16436
# 48     WV           18720
# 49     WI           19884
# 50     WY           11714

# %%
import pandas as pd
def drawingbarchart(df,col='Cumulative debt'):
    assert isinstance(col,str)
    return df.sort_values(col, ascending=False).plot.bar(x='States',y=col,rot=0,figsize=(20,10), fontsize=12)
fname = 'MERGED2010_11_PP.csv'
a = debtAvg(fname)
drawingbarchart(a)
# Out:
# C:\Users\Lewis\Anaconda2\lib\site-packages\ipykernel_launcher.py:48: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# C:\Users\Lewis\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2882: DtypeWarning: Columns (1,6,1461,1561,1729) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\Lewis\Anaconda2\lib\site-packages\ipykernel_launcher.py:56: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
